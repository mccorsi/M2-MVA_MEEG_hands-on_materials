# %% [markdown]
# # Demo 2 - Benchmarking with different datasets

# %%
import matplotlib.pyplot as plt
from mne.decoding import CSP
from pyriemann.estimation import Covariances
from pyriemann.tangentspace import TangentSpace
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC

import moabb
from moabb import benchmark, set_log_level
from moabb.analysis.plotting import score_plot
import moabb.analysis.plotting as moabb_plt
from moabb.analysis.meta_analysis import (  # noqa: E501
    compute_dataset_statistics,
    find_significant_differences,
)
from moabb.datasets import BNCI2014001, Zhou2016, Cho2017
from moabb.evaluations import CrossSessionEvaluation
from moabb.paradigms import LeftRightImagery

import seaborn as sns

moabb.set_log_level("info")
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
paradigm = LeftRightImagery()
subj = [1, 2, 3]
datasets = [BNCI2014001(), Zhou2016()]
for d in datasets:
    d.subject_list = subj

# pipelines to be compared
pipelines = {}

param_svm = {"kernel": ("linear", "rbf"), "C": [0.1, 1, 10]}
step_csp_svm = [
    ("cov", Covariances(estimator="lwf")),
    ("csp", CSP(6)),
    ("optsvm", GridSearchCV(SVC(), param_svm, cv=3)),
]
pipelines["CSP+optSVM"] = Pipeline(steps=step_csp_svm)


pipelines["CSP+LDA"] = make_pipeline(CSP(n_components=8), LDA())

pipelines["RG+LR"] = make_pipeline(Covariances(), TangentSpace(), LogisticRegression())

pipelines["CSP+LR"] = make_pipeline(CSP(n_components=8), LogisticRegression())

pipelines["RG+LDA"] = make_pipeline(Covariances(), TangentSpace(), LDA())


overwrite = True  # set to False if we want to use cached results
evaluation = CrossSessionEvaluation(
    paradigm=paradigm, datasets=datasets, suffix="stats", overwrite=overwrite
)

results = evaluation.process(pipelines)
# Out:
# 2024-02-06 16:00:38,499 INFO MainThread moabb.evaluations.base Processing dataset: 001-2014
# 001-2014-CrossSession:   0%|                                                                                  | 0/3 [00:00<?, ?it/s]2024-02-06 16:00:43,162 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_E: Score 0.856
# 2024-02-06 16:00:43,479 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_T: Score 0.768
# 2024-02-06 16:00:44,196 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_E: Score 0.955
# 2024-02-06 16:00:44,874 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_T: Score 0.932
# 2024-02-06 16:00:45,143 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_E: Score 0.963
# 2024-02-06 16:00:45,447 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_T: Score 0.950
# 2024-02-06 16:00:46,160 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_E: Score 0.969
# 2024-02-06 16:00:46,844 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_T: Score 0.954
# 2024-02-06 16:00:47,137 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_E: Score 0.878
# 2024-02-06 16:00:47,434 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_T: Score 0.861
# 001-2014-CrossSession:  33%|████████████████████████▋                                                 | 1/3 [00:08<00:17,  8.91s/it]2024-02-06 16:00:51,802 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_E: Score 0.403
# 2024-02-06 16:00:52,081 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_T: Score 0.490
# 2024-02-06 16:00:52,766 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_E: Score 0.646
# 2024-02-06 16:00:53,490 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_T: Score 0.527
# 2024-02-06 16:00:53,745 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_E: Score 0.586
# 2024-02-06 16:00:53,998 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_T: Score 0.575
# 2024-02-06 16:00:54,676 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_E: Score 0.629
# 2024-02-06 16:00:55,368 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_T: Score 0.537
# 2024-02-06 16:00:55,661 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_E: Score 0.470
# 2024-02-06 16:00:55,951 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_T: Score 0.513
# 001-2014-CrossSession:  67%|█████████████████████████████████████████████████▎                        | 2/3 [00:17<00:08,  8.68s/it]2024-02-06 16:01:00,163 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_E: Score 0.854
# 2024-02-06 16:01:00,433 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_T: Score 0.923
# 2024-02-06 16:01:01,123 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_E: Score 0.996
# 2024-02-06 16:01:01,800 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_T: Score 0.994
# 2024-02-06 16:01:02,059 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_E: Score 0.999
# 2024-02-06 16:01:02,311 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_T: Score 0.999
# 2024-02-06 16:01:03,008 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_E: Score 0.997
# 2024-02-06 16:01:03,694 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_T: Score 0.994
# 2024-02-06 16:01:03,992 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_E: Score 0.973
# 2024-02-06 16:01:04,291 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_T: Score 0.966
# 001-2014-CrossSession: 100%|██████████████████████████████████████████████████████████████████████████| 3/3 [00:25<00:00,  8.59s/it]
# 2024-02-06 16:01:04,299 INFO MainThread moabb.evaluations.base Processing dataset: Zhou 2016
# Zhou 2016-CrossSession:   0%|                                                                                 | 0/3 [00:00<?, ?it/s]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2024-02-06 16:01:08,274 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_0: Score 0.568
# 2024-02-06 16:01:08,536 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_1: Score 0.930
# 2024-02-06 16:01:08,815 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_2: Score 0.624
# 2024-02-06 16:01:09,534 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_0: Score 0.861
# 2024-02-06 16:01:10,299 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_1: Score 0.944
# 2024-02-06 16:01:11,076 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_2: Score 0.948
# 2024-02-06 16:01:11,258 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_0: Score 0.864
# 2024-02-06 16:01:11,430 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_1: Score 0.942
# 2024-02-06 16:01:11,615 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_2: Score 0.984
# 2024-02-06 16:01:12,316 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_0: Score 0.855
# 2024-02-06 16:01:13,079 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_1: Score 0.953
# 2024-02-06 16:01:13,845 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_2: Score 0.954
# 2024-02-06 16:01:14,040 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_0: Score 0.856
# 2024-02-06 16:01:14,234 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_1: Score 0.782
# 2024-02-06 16:01:14,448 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_2: Score 0.940
# Zhou 2016-CrossSession:  33%|████████████████████████▎                                                | 1/3 [00:10<00:20, 10.15s/it]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2024-02-06 16:01:17,294 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_0: Score 0.682
# 2024-02-06 16:01:17,547 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_1: Score 0.574
# 2024-02-06 16:01:17,799 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_2: Score 0.468
# 2024-02-06 16:01:18,471 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_0: Score 0.904
# 2024-02-06 16:01:19,174 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_1: Score 0.735
# 2024-02-06 16:01:19,848 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_2: Score 0.924
# 2024-02-06 16:01:20,028 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_0: Score 0.900
# 2024-02-06 16:01:20,197 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_1: Score 0.786
# 2024-02-06 16:01:20,369 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_2: Score 0.929
# 2024-02-06 16:01:21,034 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_0: Score 0.910
# 2024-02-06 16:01:21,739 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_1: Score 0.750
# 2024-02-06 16:01:22,513 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_2: Score 0.925
# 2024-02-06 16:01:22,714 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_0: Score 0.687
# 2024-02-06 16:01:22,903 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_1: Score 0.658
# 2024-02-06 16:01:23,096 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_2: Score 0.798
# Zhou 2016-CrossSession:  67%|████████████████████████████████████████████████▋                        | 2/3 [00:18<00:09,  9.27s/it]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2024-02-06 16:01:26,337 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_0: Score 0.957
# 2024-02-06 16:01:26,603 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_1: Score 0.949
# 2024-02-06 16:01:26,889 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_2: Score 0.916
# 2024-02-06 16:01:27,625 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_0: Score 0.992
# 2024-02-06 16:01:28,378 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_1: Score 0.986
# 2024-02-06 16:01:29,373 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_2: Score 0.968
# 2024-02-06 16:01:29,731 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_0: Score 0.992
# 2024-02-06 16:01:30,008 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_1: Score 0.969
# 2024-02-06 16:01:30,349 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_2: Score 0.988
# 2024-02-06 16:01:31,154 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_0: Score 0.989
# 2024-02-06 16:01:31,932 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_1: Score 0.984
# 2024-02-06 16:01:32,647 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_2: Score 0.981
# 2024-02-06 16:01:32,826 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_0: Score 0.920
# 2024-02-06 16:01:33,004 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_1: Score 0.927
# 2024-02-06 16:01:33,195 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_2: Score 0.933
# Zhou 2016-CrossSession: 100%|█████████████████████████████████████████████████████████████████████████| 3/3 [00:28<00:00,  9.63s/it]

# %%
sns.catplot(
    data=results,
    x="session",
    y="score",
    hue="subject",
    col="dataset",
    kind="bar",
    palette="viridis",
)
plt.show()
# Out:
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig = moabb_plt.score_plot(results)
plt.show()
# Out:
# 2024-02-06 16:03:19,380 WARNING MainThread moabb.analysis.plotting Dataset names are too similar, turning off name shortening
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/analysis/plotting.py:59: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sea.stripplot(

# %%
stats = compute_dataset_statistics(results)
P, T = find_significant_differences(stats)
moabb_plt.summary_plot(P, T)
plt.show()

# %%
fig = moabb_plt.meta_analysis_plot(stats, "CSP+LDA", "RG+LR")
plt.show()
