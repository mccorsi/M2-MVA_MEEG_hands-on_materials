# %%
import matplotlib.pyplot as plt
from mne.decoding import CSP
from pyriemann.estimation import Covariances
from pyriemann.tangentspace import TangentSpace
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC

import moabb
from moabb import benchmark, set_log_level
from moabb.analysis.plotting import score_plot
import moabb.analysis.plotting as moabb_plt
from moabb.analysis.meta_analysis import (  # noqa: E501
    compute_dataset_statistics,
    find_significant_differences,
)
from moabb.datasets import BNCI2014001, Zhou2016, Cho2017
from moabb.evaluations import CrossSessionEvaluation
from moabb.paradigms import LeftRightImagery

import seaborn as sns

moabb.set_log_level("info")
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
# pipelines to be compared

pipelines = {}

param_svm = {"kernel": ("linear", "rbf"), "C": [0.1, 1, 10]}
step_csp_svm = [
    ("cov", Covariances(estimator="lwf")),
    ("csp", CSP(6)),
    ("optsvm", GridSearchCV(SVC(), param_svm, cv=3)),
]
pipelines["CSP+optSVM"] = Pipeline(steps=step_csp_svm)


pipelines["CSP+LDA"] = make_pipeline(CSP(n_components=8), LDA())

pipelines["RG+LR"] = make_pipeline(Covariances(), TangentSpace(), LogisticRegression())

pipelines["CSP+LR"] = make_pipeline(CSP(n_components=8), LogisticRegression())

pipelines["RG+LDA"] = make_pipeline(Covariances(), TangentSpace(), LDA())

# %%
# evaluation on one dataset

paradigm = LeftRightImagery()
dataset = BNCI2014001()
dataset.subject_list = dataset.subject_list[:4]
datasets = [dataset]
overwrite = True  # set to False if we want to use cached results
evaluation = CrossSessionEvaluation(
    paradigm=paradigm, datasets=datasets, suffix="stats", overwrite=overwrite
)

results = evaluation.process(pipelines)
# Out:
# 2024-02-06 15:35:16,506 INFO MainThread moabb.evaluations.base Processing dataset: 001-2014
# 001-2014-CrossSession:   0%|                                                                                  | 0/4 [00:00<?, ?it/s]2024-02-06 15:35:21,334 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_E: Score 0.856
# 2024-02-06 15:35:21,621 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_T: Score 0.768
# 2024-02-06 15:35:22,321 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_E: Score 0.955
# 2024-02-06 15:35:23,010 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_T: Score 0.932
# 2024-02-06 15:35:23,306 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_E: Score 0.963
# 2024-02-06 15:35:23,584 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_T: Score 0.950
# 2024-02-06 15:35:24,267 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_E: Score 0.969
# 2024-02-06 15:35:24,942 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_T: Score 0.954
# 2024-02-06 15:35:25,283 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_E: Score 0.878
# 2024-02-06 15:35:25,599 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_T: Score 0.861
# 001-2014-CrossSession:  25%|██████████████████▌                                                       | 1/4 [00:08<00:26,  8.90s/it]2024-02-06 15:35:29,883 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_E: Score 0.403
# 2024-02-06 15:35:30,170 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_T: Score 0.490
# 2024-02-06 15:35:30,892 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_E: Score 0.646
# 2024-02-06 15:35:31,611 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_T: Score 0.527
# 2024-02-06 15:35:31,905 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_E: Score 0.586
# 2024-02-06 15:35:32,215 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_T: Score 0.575
# 2024-02-06 15:35:32,932 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_E: Score 0.629
# 2024-02-06 15:35:33,651 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_T: Score 0.537
# 2024-02-06 15:35:33,963 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_E: Score 0.470
# 2024-02-06 15:35:34,292 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_T: Score 0.513
# 001-2014-CrossSession:  50%|█████████████████████████████████████                                     | 2/4 [00:17<00:17,  8.78s/it]2024-02-06 15:35:38,475 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_E: Score 0.854
# 2024-02-06 15:35:38,741 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_T: Score 0.923
# 2024-02-06 15:35:39,433 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_E: Score 0.996
# 2024-02-06 15:35:40,115 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_T: Score 0.994
# 2024-02-06 15:35:40,390 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_E: Score 0.999
# 2024-02-06 15:35:40,666 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_T: Score 0.999
# 2024-02-06 15:35:41,340 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_E: Score 0.997
# 2024-02-06 15:35:42,021 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_T: Score 0.994
# 2024-02-06 15:35:42,332 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_E: Score 0.973
# 2024-02-06 15:35:42,640 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_T: Score 0.966
# 001-2014-CrossSession:  75%|███████████████████████████████████████████████████████▌                  | 3/4 [00:25<00:08,  8.58s/it]2024-02-06 15:35:46,734 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 4 | session_E: Score 0.608
# 2024-02-06 15:35:47,010 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 4 | session_T: Score 0.639
# 2024-02-06 15:35:47,712 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 4 | session_E: Score 0.829
# 2024-02-06 15:35:48,392 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 4 | session_T: Score 0.829
# 2024-02-06 15:35:48,673 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 4 | session_E: Score 0.877
# 2024-02-06 15:35:48,931 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 4 | session_T: Score 0.858
# 2024-02-06 15:35:49,625 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 4 | session_E: Score 0.837
# 2024-02-06 15:35:50,303 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 4 | session_T: Score 0.835
# 2024-02-06 15:35:50,610 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 4 | session_E: Score 0.721
# 2024-02-06 15:35:50,913 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 4 | session_T: Score 0.690
# 001-2014-CrossSession: 100%|██████████████████████████████████████████████████████████████████████████| 4/4 [00:34<00:00,  8.55s/it]

# %%
# plot comparison
fig = moabb_plt.score_plot(results)
plt.show()
# Out:
# 2024-02-06 15:36:27,990 WARNING MainThread moabb.analysis.plotting Dataset names are too similar, turning off name shortening
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/analysis/plotting.py:59: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sea.stripplot(

# %%
fig = moabb_plt.paired_plot(results, "CSP+LDA", "RG+LDA")
plt.show()

# %%
# plot statistical comparison
stats = compute_dataset_statistics(results)
P, T = find_significant_differences(stats)

fig = moabb_plt.meta_analysis_plot(stats, "CSP+LDA", "RG+LDA")
plt.show()

# %%
moabb_plt.summary_plot(P, T)
plt.show()

# %%
paradigm = LeftRightImagery()
subj = [1, 2, 3]
datasets = [BNCI2014001(), Zhou2016()]
for d in datasets:
    d.subject_list = subj

overwrite = True  # set to False if we want to use cached results
evaluation = CrossSessionEvaluation(
    paradigm=paradigm, datasets=datasets, suffix="stats", overwrite=overwrite
)

results = evaluation.process(pipelines)
# Out:
# 2024-02-06 15:36:47,071 INFO MainThread moabb.evaluations.base Processing dataset: 001-2014
# 001-2014-CrossSession:   0%|                                                                                  | 0/3 [00:00<?, ?it/s]2024-02-06 15:36:51,652 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_E: Score 0.856
# 2024-02-06 15:36:51,930 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_T: Score 0.768
# 2024-02-06 15:36:52,731 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_E: Score 0.955
# 2024-02-06 15:36:53,614 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_T: Score 0.932
# 2024-02-06 15:36:53,949 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_E: Score 0.963
# 2024-02-06 15:36:54,242 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_T: Score 0.950
# 2024-02-06 15:36:54,912 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_E: Score 0.969
# 2024-02-06 15:36:55,611 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_T: Score 0.954
# 2024-02-06 15:36:55,918 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_E: Score 0.878
# 2024-02-06 15:36:56,240 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_T: Score 0.861
# 001-2014-CrossSession:  33%|████████████████████████▋                                                 | 1/3 [00:09<00:18,  9.17s/it]2024-02-06 15:37:00,585 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_E: Score 0.403
# 2024-02-06 15:37:00,862 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_T: Score 0.490
# 2024-02-06 15:37:01,545 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_E: Score 0.646
# 2024-02-06 15:37:02,216 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_T: Score 0.527
# 2024-02-06 15:37:02,495 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_E: Score 0.586
# 2024-02-06 15:37:02,773 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_T: Score 0.575
# 2024-02-06 15:37:03,451 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_E: Score 0.629
# 2024-02-06 15:37:04,141 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_T: Score 0.537
# 2024-02-06 15:37:04,467 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_E: Score 0.470
# 2024-02-06 15:37:04,776 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_T: Score 0.513
# 001-2014-CrossSession:  67%|█████████████████████████████████████████████████▎                        | 2/3 [00:17<00:08,  8.80s/it]2024-02-06 15:37:08,997 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_E: Score 0.854
# 2024-02-06 15:37:09,269 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_T: Score 0.923
# 2024-02-06 15:37:09,954 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_E: Score 0.996
# 2024-02-06 15:37:10,621 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_T: Score 0.994
# 2024-02-06 15:37:10,899 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_E: Score 0.999
# 2024-02-06 15:37:11,177 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_T: Score 0.999
# 2024-02-06 15:37:11,848 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_E: Score 0.997
# 2024-02-06 15:37:12,537 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_T: Score 0.994
# 2024-02-06 15:37:12,847 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_E: Score 0.973
# 2024-02-06 15:37:13,158 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_T: Score 0.966
# 001-2014-CrossSession: 100%|██████████████████████████████████████████████████████████████████████████| 3/3 [00:26<00:00,  8.70s/it]
# 2024-02-06 15:37:13,166 INFO MainThread moabb.evaluations.base Processing dataset: Zhou 2016
# Zhou 2016-CrossSession:   0%|                                                                                 | 0/3 [00:00<?, ?it/s]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2024-02-06 15:37:17,181 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_0: Score 0.568
# 2024-02-06 15:37:17,444 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_1: Score 0.930
# 2024-02-06 15:37:17,724 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_2: Score 0.624
# 2024-02-06 15:37:18,441 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_0: Score 0.861
# 2024-02-06 15:37:19,209 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_1: Score 0.944
# 2024-02-06 15:37:19,968 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_2: Score 0.948
# 2024-02-06 15:37:20,168 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_0: Score 0.864
# 2024-02-06 15:37:20,363 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_1: Score 0.942
# 2024-02-06 15:37:20,569 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_2: Score 0.984
# 2024-02-06 15:37:21,271 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_0: Score 0.855
# 2024-02-06 15:37:22,044 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_1: Score 0.953
# 2024-02-06 15:37:22,811 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_2: Score 0.954
# 2024-02-06 15:37:23,030 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_0: Score 0.856
# 2024-02-06 15:37:23,248 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_1: Score 0.782
# 2024-02-06 15:37:23,475 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_2: Score 0.940
# Zhou 2016-CrossSession:  33%|████████████████████████▎                                                | 1/3 [00:10<00:20, 10.31s/it]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2024-02-06 15:37:26,395 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_0: Score 0.682
# 2024-02-06 15:37:26,648 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_1: Score 0.574
# 2024-02-06 15:37:26,898 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_2: Score 0.468
# 2024-02-06 15:37:27,572 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_0: Score 0.904
# 2024-02-06 15:37:28,275 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_1: Score 0.735
# 2024-02-06 15:37:28,945 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_2: Score 0.924
# 2024-02-06 15:37:29,145 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_0: Score 0.900
# 2024-02-06 15:37:29,334 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_1: Score 0.786
# 2024-02-06 15:37:29,530 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_2: Score 0.929
# 2024-02-06 15:37:30,204 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_0: Score 0.910
# 2024-02-06 15:37:30,917 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_1: Score 0.750
# 2024-02-06 15:37:31,599 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_2: Score 0.925
# 2024-02-06 15:37:31,853 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_0: Score 0.687
# 2024-02-06 15:37:32,152 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_1: Score 0.658
# 2024-02-06 15:37:32,381 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_2: Score 0.798
# Zhou 2016-CrossSession:  67%|████████████████████████████████████████████████▋                        | 2/3 [00:19<00:09,  9.49s/it]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2024-02-06 15:37:35,508 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_0: Score 0.957
# 2024-02-06 15:37:35,757 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_1: Score 0.949
# 2024-02-06 15:37:36,018 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_2: Score 0.916
# 2024-02-06 15:37:36,744 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_0: Score 0.992
# 2024-02-06 15:37:37,478 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_1: Score 0.986
# 2024-02-06 15:37:38,213 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_2: Score 0.968
# 2024-02-06 15:37:38,402 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_0: Score 0.992
# 2024-02-06 15:37:38,595 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_1: Score 0.969
# 2024-02-06 15:37:38,788 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_2: Score 0.988
# 2024-02-06 15:37:39,573 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_0: Score 0.989
# 2024-02-06 15:37:40,330 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_1: Score 0.984
# 2024-02-06 15:37:41,080 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_2: Score 0.981
# 2024-02-06 15:37:41,283 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_0: Score 0.920
# 2024-02-06 15:37:41,484 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_1: Score 0.927
# 2024-02-06 15:37:41,693 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_2: Score 0.933
# Zhou 2016-CrossSession: 100%|█████████████████████████████████████████████████████████████████████████| 3/3 [00:28<00:00,  9.51s/it]

# %%
sns.catplot(
    data=results,
    x="session",
    y="score",
    hue="subject",
    col="dataset",
    kind="bar",
    palette="viridis",
)
plt.show()
# Out:
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig = moabb_plt.score_plot(results)
plt.show()
# Out:
# 2024-02-06 15:39:08,376 WARNING MainThread moabb.analysis.plotting Dataset names are too similar, turning off name shortening
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/analysis/plotting.py:59: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sea.stripplot(

# %%
stats = compute_dataset_statistics(results)
P, T = find_significant_differences(stats)
moabb_plt.summary_plot(P, T)
plt.show()

# %%
fig = moabb_plt.meta_analysis_plot(stats, "CSP+LDA", "RG+LR")
plt.show()

# %% [markdown]
# # Demo 3 - Use of alternative features based on functional connectivity - Code based on this [tutorial](https://pyriemann.readthedocs.io/en/latest/auto_examples/motor-imagery/plot_ensemble_coherence.html)

# %%
import matplotlib.pyplot as plt

from mne import Epochs, pick_types, events_from_annotations
from mne.io import concatenate_raws
from mne.io.edf import read_raw_edf
from mne.datasets import eegbci

import numpy as np
import pandas as pd
import seaborn as sns

from pyriemann.classification import FgMDM
from pyriemann.estimation import Covariances, Coherences
from pyriemann.spatialfilters import CSP
from pyriemann.tangentspace import TangentSpace

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC


from helpers.coherence_helpers import (
    NearestSPD,
    get_results,
) # put "helpers" folder in the pyriemann's one

# %% [markdown]
# ## Connectivity transformer to compute FC estimations

# %%
class Connectivities(TransformerMixin, BaseEstimator):
    """Getting connectivity features from epoch"""

    def __init__(self, method="ordinary", fmin=8, fmax=35, fs=None):
        self.method = method
        self.fmin = fmin
        self.fmax = fmax
        self.fs = fs

    def fit(self, X, y=None):
        self._coh = Coherences(
            coh=self.method,
            fmin=self.fmin,
            fmax=self.fmax,
            fs=self.fs,
        )
        return self

    def transform(self, X):
        X_coh = self._coh.fit_transform(X)
        X_con = np.mean(X_coh, axis=-1, keepdims=False)
        return X_con

# %% [markdown]
# ## EEG data

# %%
# avoid classification of evoked responses by using epochs that start 1s after cue onset.
tmin, tmax = 1.0, 2.0
event_id = dict(hands=2, feet=3)
subject = 7
runs = [4, 8]  # motor imagery: left vs right hand

raw_files = [
    read_raw_edf(f, preload=True) for f in eegbci.load_data(subject, runs)
]
raw = concatenate_raws(raw_files)

picks = pick_types(
    raw.info, meg=False, eeg=True, stim=False, eog=False, exclude="bads"
)
# subsample elecs
picks = picks[::2]

# Apply band-pass filter
raw.filter(7.0, 35.0, method="iir", picks=picks)

events, _ = events_from_annotations(raw, event_id=dict(T1=2, T2=3))

# Read epochs (train will be done only between 1 and 2s)
epochs = Epochs(
    raw,
    events,
    event_id,
    tmin,
    tmax,
    proj=True,
    picks=picks,
    baseline=None,
    preload=True,
    verbose=False,
)
labels = epochs.events[:, -1] - 2
fs = epochs.info["sfreq"]
X = 1e6 * epochs.get_data()
# Out:
# Extracting EDF parameters from /Users/marieconstance.corsi/Documents/GitHub/M2-MVA_MEEG_hands-on_materials/datasets/MNE-eegbci-data/files/eegmmidb/1.0.0/S007/S007R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/marieconstance.corsi/Documents/GitHub/M2-MVA_MEEG_hands-on_materials/datasets/MNE-eegbci-data/files/eegmmidb/1.0.0/S007/S007R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Filtering a subset of channels. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 2 contiguous segments
# Setting up band-pass filter from 7 - 35 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 7.00, 35.00 Hz: -6.02, -6.02 dB
#
# Used Annotations descriptions: ['T1', 'T2']

# %%
spectral_met = ["cov", "lagged", "instantaneous"]
fmin, fmax = 8, 35

# plot infos features
idx_left=np.where(labels==0)
idx_right=np.where(labels==1)

X_left=np.squeeze(X[idx_left,:,:])
X_right=np.squeeze(X[idx_right,:,:])

mat_connect_left=dict()
mat_connect_right=dict()

param_ft = {"fmin": fmin, "fmax": fmax, "fs": fs}
for sm in spectral_met:
    if sm == "cov":
        Y=Covariances(estimator="lwf").transform(X)
        mat_connect_left[sm]=Y[idx_left,:,:]
        mat_connect_right[sm]=Y[idx_right,:,:]
    else:
        Y=Coherences(coh=sm, fmin=fmin, fmax=fmax, fs=fs).transform(X)
        avg_freqBand=Y.mean(axis=3)
        mat_connect_left[sm]=np.mean(np.squeeze(avg_freqBand[idx_left,:,:]),0) # direct averaged over the trials
        mat_connect_right[sm]=np.mean(np.squeeze(avg_freqBand[idx_right,:,:]),0)
        
        
# plot FC
sm=spectral_met[2]

fig, axes = plt.subplots(1,2, figsize=[8, 3])
ch_names = [ch.replace('.', '') for ch in epochs.ch_names]

df = pd.DataFrame(data=mat_connect_left[sm], index=ch_names, columns=ch_names)
g = sns.heatmap(
                df, ax=axes[0], square=True, cbar=True, xticklabels=2, yticklabels=2)
g.set_title('Mean ' + sm + ' - left MI')

df = pd.DataFrame(data=mat_connect_right[sm], index=ch_names, columns=ch_names)
g = sns.heatmap(
                df, ax=axes[1], square=True, cbar=True, xticklabels=2, yticklabels=2)
g.set_title('Mean ' + sm + ' - right MI')

plt.xticks(rotation='vertical')
plt.yticks(rotation='horizontal')
plt.show()


fig, axes = plt.subplots(figsize=[8, 4])
ch_names = [ch.replace('.', '') for ch in epochs.ch_names]

df = pd.DataFrame(data=mat_connect_right[sm]-mat_connect_left[sm], index=ch_names, columns=ch_names)
g = sns.heatmap(
                df, ax=axes, square=True, cbar=True, xticklabels=2, yticklabels=2, cmap="vlag")
g.set_title('Difference Right - Left ' + sm )

plt.xticks(rotation='vertical')
plt.yticks(rotation='horizontal')
plt.show()

# %% [markdown]
# ## Pipelines definition

# %% [markdown]
# Here we are going to compare different methods: CSP+shLDA, CSP+SVM, FgMDM on covariance, tangent space logistic regression with covariance, lag coherence, and instantaneous coherence, along with ensemble method

# %%
ppl_baseline, ppl_fc, ppl_ens = {}, {}, {}

# %%
# Baseline pipelines
param_svm = {"kernel": ("linear", "rbf"), "C": [0.1, 1, 10]}
step_csp_svm = [
    ("cov", Covariances(estimator="lwf")),
    ("csp", CSP(nfilter=6)),
    ("optsvm", GridSearchCV(SVC(), param_svm, cv=3)),
]
ppl_baseline["CSP+optSVM"] = Pipeline(steps=step_csp_svm)


step_mdm = [
    ("cov", Covariances(estimator="lwf")),
    ("fgmdm", FgMDM(metric="riemann", tsupdate=False)),
]
ppl_baseline["FgMDM"] = Pipeline(steps=step_mdm)

# %%
# Functional connectivity pipelines
spectral_met = ["cov", "lagged", "instantaneous"]
fmin, fmax = 8, 35
param_lr = {
    "penalty": "elasticnet",
    "l1_ratio": 0.15,
    "intercept_scaling": 1000.0,
    "solver": "saga",
}
param_ft = {"fmin": fmin, "fmax": fmax, "fs": fs}
step_fc = [
    ("spd", NearestSPD()),
    ("tg", TangentSpace(metric="riemann")),
    ("LogistReg", LogisticRegression(**param_lr)),
]
for sm in spectral_met:
    pname = sm + "+elasticnet"
    if sm == "cov":
        ppl_fc[pname] = Pipeline(
            steps=[("cov", Covariances(estimator="lwf"))] + step_fc
        )
    else:
        ft = Connectivities(**param_ft, method=sm)
        ppl_fc[pname] = Pipeline(steps=[("ft", ft)] + step_fc)

# %%
# Ensemble classifier
fc_estim = [(n, ppl_fc[n]) for n in ppl_fc]
cvkf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

lr = LogisticRegression(**param_lr)
ppl_ens["ensemble"] = StackingClassifier(
    estimators=fc_estim,
    cv=cvkf,
    n_jobs=1,
    final_estimator=lr,
    stack_method="predict_proba",
)

# %% [markdown]
# ### Evaluation

# %%
dataset_res = list()
all_ppl = {**ppl_baseline, **ppl_ens}
#print(all_ppl)

# %%
# Compute results
results = get_results(X, labels, all_ppl)
results = pd.DataFrame(results)
# Out:
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/pyriemann/utils/mean.py:540: UserWarning: Convergence not reached
#   warnings.warn("Convergence not reached")
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
results
# Out:
#        score                  pipeline  split  samples
# 0   0.750000                CSP+optSVM      0       30
# 1   0.750000                     FgMDM      0       30
# 2   1.000000                  ensemble      0       30
# 3   0.750000            cov+elasticnet      0       30
# 4   0.125000         lagged+elasticnet      0       30
# 5   0.500000  instantaneous+elasticnet      0       30
# 6   0.666667                CSP+optSVM      1       30
# 7   0.666667                     FgMDM      1       30
# 8   0.833333                  ensemble      1       30
# 9   0.833333            cov+elasticnet      1       30
# 10  0.333333         lagged+elasticnet      1       30
# 11  0.500000  instantaneous+elasticnet      1       30
# 12  1.000000                CSP+optSVM      2       30
# 13  0.666667                     FgMDM      2       30
# 14  1.000000                  ensemble      2       30
# 15  1.000000            cov+elasticnet      2       30
# 16  0.166667         lagged+elasticnet      2       30
# 17  0.500000  instantaneous+elasticnet      2       30
# 18  0.833333                CSP+optSVM      3       30
# 19  0.666667                     FgMDM      3       30
# 20  1.000000                  ensemble      3       30
# 21  1.000000            cov+elasticnet      3       30
# 22  0.333333         lagged+elasticnet      3       30
# 23  0.666667  instantaneous+elasticnet      3       30
# 24  1.000000                CSP+optSVM      4       30
# 25  0.833333                     FgMDM      4       30
# 26  1.000000                  ensemble      4       30
# 27  1.000000            cov+elasticnet      4       30
# 28  0.166667         lagged+elasticnet      4       30
# 29  0.666667  instantaneous+elasticnet      4       30

# %%
# plot results
list_fc_ens = ["ensemble", "CSP+optSVM", "FgMDM"] + \
    [sm + "+elasticnet" for sm in spectral_met]

g = sns.catplot(
    data=results,
    x="pipeline",
    y="score",
    kind="bar",
    order=list_fc_ens,
    height=7,
    aspect=2,
)
plt.show()
# Out:
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
